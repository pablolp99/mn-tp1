# %%
import numpy as np

rs = np.random.RandomState(np.random.MT19937(np.random.SeedSequence(42)))

# # Input
# TEMP_INT = np.array([1500 for i in range(N_DEGREES)])
# TEMP_EXT = np.random.uniform(low=120.0, high=180.0, size=N_DEGREES)
# (loc=150, scale=10, size=)
RADIUSES = np.linspace(INTERNAL_RADIUS, EXTERNAL_RADIUS, M_1_RADIUS+1)
DEGREES = np.linspace(0.0, 2*np.pi, N_DEGREES)

# %%
def create_instances(loc=350.0, scale=1.0):
    print(INTERNAL_RADIUS, EXTERNAL_RADIUS, M_1_RADIUS, N_DEGREES, ISOTERMA, INSTANCES)
    
    for _ in range(INSTANCES):
        internal_temps = np.random.normal(loc=loc, scale=scale, size=N_DEGREES)
        print(" ".join(list(map(str, TEMP_INT))), " ".join(list(map(str, internal_temps))))

# %%
create_instances(loc=350, scale=25)
# Out:
# 5.0 6.0 32 32 500 10
# 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 318.9174589896416 339.2333185566741 336.3600303476007 344.3152403418491 352.69274160062525 330.6952413403084 370.7242324803516 323.96457002692193 369.70486721182505 356.84227459765003 309.69929082597366 343.4268488785081 358.7124375454635 331.8755338651552 328.00719824233653 332.76429471753124 382.4064361324643 375.5179679998547 390.66246271502166 356.78591500092574 334.8779474624868 339.3394736635854 331.0754033381487 357.63288738968123 332.61317980948144 370.1157088870622 392.75562804620955 342.2069394360864 391.5379526013945 333.6931041215042 350.70942632231106 341.0417860594011
# ...
